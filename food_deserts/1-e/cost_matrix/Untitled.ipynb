# %%
import pandas as pd
import numpy as np

# %%
a =pd.read_csv("cost_matrix_1e.csv",header = None)

# %%
a = np.array(a)

# %%
os.listdir("../../1-e")
# Out:
# ['cost_matrix']

# %%
np.savetxt("../../1-e/cost_matrix/cost_matrix_1e.csv",
           a, delimiter=',')

# %%
a[a < 10] = 10

# %%
pd.read_csv("../../outputs/data.csv")
# Out:
#      Unnamed: 0   latitude  longitude  venta_frutas  venta_verduras  \
# 0             0 -12.038805 -76.947609             1               1
# 1             1 -11.962990 -77.019870             1               1
# 2             2 -12.008620 -76.976800             1               1
# 3             3 -12.118304 -77.024742             0               1
# 4             4 -12.118167 -77.024822             0               1
# ..          ...        ...        ...           ...             ...
# 250         250 -12.227278 -76.957982             1               1
# 251         251 -12.219718 -76.944915             1               0
# 252         252 -12.224536 -76.949702             1               1
# 253         253 -12.008637 -76.976799             1               1
# 254         254 -12.001251 -76.986144             1               1
#
#      superficie_bodega  num_personas hora_apertura_semana hora_cierre_semana  \
# ...

# %%
(pd.read_csv("duration_matrix_vende-fyv.csv",header = None))/60
# Out:
#            0          1          2          3          4          5    \
# 0     0.000000  19.289000  32.128500  32.177333  32.207500  32.190333
# 1    20.148000   0.000000  23.778333  23.827167  23.857500  23.840167
# 2    31.990667  23.875167   0.000000   0.048833   0.079000   0.061833
# 3    31.941833  23.826333   1.059333   0.000000   0.030333   0.013000
# 4    31.911667  23.796000   1.029167   1.078000   0.000000   1.091000
# ..         ...        ...        ...        ...        ...        ...
# 249  47.072000  36.910167  24.657500  24.706333  24.736500  24.719333
# 250  44.378167  34.216333  21.963667  22.012500  22.042667  22.025500
# 251  45.263500  35.101833  22.849167  22.898000  22.928167  22.910833
# 252  20.146333   0.001667  23.776833  23.825667  23.855833  23.838667
# 253  17.084667  12.125167  26.104833  26.153667  26.183833  26.166667
#
#            6          7          8          9    ...        244        245  \
# ...
